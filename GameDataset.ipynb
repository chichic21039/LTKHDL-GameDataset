# %% [markdown]
# # Group information: <br>
# Phạm Khánh Linh 23127083 <br>
# Võ Trung Hiếu 23127190<br>
# Võ Hoàng Thương 23127493<br>

# %% [markdown]
# # 1. Data collection

# %% [markdown]
# 1. Đề tài của bộ dữ liệu <br>
# - Bộ dữ liệu thuộc lĩnh vực ngành công nghiệp game, chứa thông tin về các trò chơi điện tử và số liệu doanh số bán hàng của chúng trên nhiều nền tảng.
#
# - Bộ dữ liệu phản ánh thực trạng thị trường game thế giới, bao gồm doanh số thực tế, nền tảng phát hành và mức độ phổ biến của từng tựa game.

# %% [markdown]
# 2. Nguồn dữ liệu <br>
# - Nguồn dữ liệu được thu thập và chia sẻ trên Kaggle:
# https://www.kaggle.com/datasets/gsimonx37/vgchartz
# - Tác giả đăng tải trên Kaggle là gsimonx37; dữ liệu gốc tổng hợp từ VGChartz, một trang theo dõi doanh số game toàn cầu.
# - Bộ dữ liệu được tải lên Kaggle vào năm 2024 (thời điểm thu thập theo mô tả trên trang dataset).

# %% [markdown]
# Is this data licensed for your use? (Hiếu)<br>
# • What license does the dataset have?<br>
# • Are you permitted to use it for educational purposes?<br>
# • Document any usage restrictions or attribution requirements<br>

# %% [markdown]
# How was this data collected? (Thương)<br>
# • Collection method (survey, sensors, administrative records, web scraping, etc.)<br>
# • Target population and sampling approach<br>
# • Time period of data collection<br>
# • Any known limitations or biases in collection<br>

# %% [markdown]
# Why did you choose this dataset? (Hiếu)<br>
# • What interests your group about this topic?<br>
# • What potential questions or insights could this data provide?<br>
