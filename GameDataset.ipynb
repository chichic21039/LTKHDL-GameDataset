# %% [markdown]
# # Group information: <br>
# Phạm Khánh Linh 23127083 <br>
# Võ Trung Hiếu 23127190<br>
# Võ Hoàng Thương 23127493<br>

# %% [markdown]
# # 1. Data collection

# %% [markdown]
# ## 1.1 Đề tài của bộ dữ liệu <br>
# - Bộ dữ liệu thuộc lĩnh vực ngành công nghiệp game, chứa thông tin về các trò chơi điện tử và số liệu doanh số bán hàng của chúng trên nhiều nền tảng.
#
# - Bộ dữ liệu phản ánh thực trạng thị trường game thế giới, bao gồm doanh số thực tế, nền tảng phát hành và mức độ phổ biến của từng tựa game.

# %% [markdown]
# ## 1.2 Nguồn dữ liệu <br>
# - Nguồn dữ liệu được thu thập và chia sẻ trên Kaggle:
# https://www.kaggle.com/datasets/gsimonx37/vgchartz
# - Tác giả đăng tải trên Kaggle là gsimonx37; dữ liệu gốc tổng hợp từ VGChartz, một trang theo dõi doanh số game toàn cầu.
# - Bộ dữ liệu được tải lên Kaggle vào năm 2024 (thời điểm thu thập theo mô tả trên trang dataset).

# %% [markdown]
# ## 1.3 Được cấp phép sử dụng dữ liệu không?
#
# - GPLv3
# - Có thể dùng được cho mục đích học tập (trích trong văn bản giấy phép đoạn: This License explicitly affirms your unlimited permission to run the unmodified Program.)
# - GPLv3 hầu như không có giới hạn gì về việc sử dụng (running) phần mềm (Nhưng cần lưu ý rằng không được áp đặt bất kỳ hạn chế nào nữa đối với việc thực hiện các quyền được cấp hoặc xác nhận theo Giấy phép này)
# - Chỉ có yêu cầu ghi công khi phát hành lại phần mềm, không áp dụng khi chỉ dùng nội bộ hoặc dạy học mà không phát hành.
#     - Nhưng nếu phát hành lại bản gốc: Giữ nguyên copyright notice, giữ nguyên tất cả thông báo “Licensed under GPLv3”, kèm theo một bản sao GPLv3.
#     - Phát hành bản đã sửa đổi: Thêm dòng thông báo bạn đã sửa đổi + ngày, thông báo rõ là phát hành dưới GPLv3, giữ nguyên các notice cũ.

# %% [markdown]
# ## 1.4 Dữ liệu được thu thập như thế nào
# ### 1.4.1 Phương pháp thu thập
# • Dữ liệu được tác giả thu thập bằng phương pháp web scraping từ trang vgchartz.com.
# ### 1.4.2 Đối tượng mục tiêu và phương pháp lấy mẫu:
# • Đối tượng mục tiêu: là dữ liệu doanh số các tựa game trên toàn cầu, nhưng chủ yếu trung vào game bán lẻ(retail) vì VGCharts đã ngừng ước tính  tính doanh số kỹ thuật số từ 2018
#
# • Phương pháp lấy mẫu: Ở đây tác giả không đề cập đến sẽ lấy các mẫu nào chỉ nói đến việc thu thập dữ liệu bằng một chương trình tự động, tức là lấy mẫu toàn bộ dữ liệu bao gồm tất cả các tựa game có sẵn trên VGCharts
# ### 1.4.3 Khoảng thời gian thu thập dữ liệu
# Tác giả không đề cập đến thời gian cào dữ liệu nhưng trang web VGChartz được thành lập từ (2005) và từ năm 2018 trở đi thì VGChart ngừng ước tính doanh số phần mềm vì thị trường kỹ thuật số chiếm tỷ trọng lớn,khó đo lường và dữ liệu chỉ có trường "date" là ngày phát hành game và không có ngày công bố trên VGChart, dữ liệu ngày phát hành game với khoảng vùng 01-01-1970 đến 31-12-2024
# ### 1.4.4 Hạn chế và bias dữ liệu
# Do sau năm 2018 VGChart ngừng ước tính doanh số phần mềm nên dữ liệu chủ yếu phản ánh doanh số bán lẻ vật lý, nên có thể dữ liệu về doanh số phần mềm sẽ bị thiếu hoặc ít và phần lớn dữ liệu doanh số cũng chỉ là ước tính từ VGChart chỉ một số ít là từ nhà phát hành nên cũng có thể có rủi ro về ước tính

# %% [markdown]
# ## 1.5 Lý do chọn tập dữ liệu
#
# Chúng em chọn dataset VGChartz (Video Game Sales) vì:
#
# - Chủ đề cực kỳ hấp dẫn và gần gũi: ngành game hiện lớn hơn cả phim và nhạc cộng lại, mọi thành viên trong nhóm đều đam mê và muốn khám phá lý do vì sao một số game thành “huyền thoại” về doanh số.
# - Nguồn dữ liệu uy tín: VGChartz là một trong những trang theo dõi doanh số game nổi tiếng nhất thế giới, được giới chuyên môn tin dùng nhiều năm.
# - Rất giàu thông tin: hơn 55.000 tựa game với doanh số theo khu vực, nền tảng, nhà phát hành, điểm đánh giá – đủ để làm từ phân tích cơ bản đến mô hình dự đoán doanh số.
# - Phù hợp mọi trình độ
# - Dữ liệu đã khá sạch và dễ tiếp cận trên Kaggle.
#
# Dataset VGChartz cho phép trả lời rất nhiều câu hỏi thú vị như:
#
# - Năm nào là đỉnh cao của ngành game về số lượng và doanh số?
# - Tháng nào trong năm là mùa phát hành game nóng nhất và vì sao?
# - Thị trường Nhật Bản khác biệt thế nào so với Bắc Mỹ và châu Âu?
# - Nền tảng và nhà phát hành nào thống trị ngành qua các thời kỳ?
# - Điểm số của giới phê bình và người chơi có thực sự quyết định doanh số không?
# - Dataset này không chỉ cho chúng em thấy ai bán chạy nhất, mà còn giúp hiểu rõ công thức thành công thực sự của một tựa game trong ngành công nghiệp hàng trăm tỷ đô la này.

# %% [markdown]
# # 2. Khám phá dữ liệu

# %% [markdown]
# Đọc file lưu vào dataframe.

# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("vgchartz.csv")

# %%
print(df.head(10))
# Out:
#                name        date platform  \
# 0            Tetris  1988-01-01   Series
# 1           Pokemon  1998-09-28   Series
# 2      Call of Duty  2003-10-29   Series
# 3  Grand Theft Auto  1998-03-27   Series
# 4       Super Mario  1983-07-20   Series
# 5              FIFA  1993-12-15   Series
# 6         Minecraft  2011-11-18   Series
# 7         Minecraft  2011-11-18      All
# 8              Lego  1997-09-26   Series
# 9  Assassin's Creed  2007-11-13   Series
#
#                                 publisher  \
# 0                      The Tetris Company
# 1                                Nintendo
# 2                              Activision
# 3                          Rockstar Games
# 4                                Nintendo
# 5                               EA Sports
# 6                                  Mojang
# 7                                  Mojang
# 8  Warner Bros. Interactive Entertainment
# 9                                 Ubisoft
#
#                                developer  shipped  total  america  europe  \
# 0                        Alexey Pajitnov   520.00    NaN      NaN     NaN
# 1                             Game Freak   481.46    NaN      NaN     NaN
# 2                          Infinity Ward   425.00    NaN      NaN     NaN
# 3                         Rockstar North   410.00    NaN      NaN     NaN
# 4                               Nintendo   408.92    NaN      NaN     NaN
# 5  Extended Play Productions (1991-1997)   325.00    NaN      NaN     NaN
# 6                                 Mojang   300.00    NaN      NaN     NaN
# 7                              Mojang AB   300.00    NaN      NaN     NaN
# 8                              TT Fusion   203.22    NaN      NaN     NaN
# 9                                Ubisoft   200.00    NaN      NaN     NaN
#
#    japan  other  vgc  critic  user
# 0    NaN    NaN  NaN     NaN   NaN
# 1    NaN    NaN  NaN     NaN   NaN
# 2    NaN    NaN  NaN     NaN   NaN
# 3    NaN    NaN  NaN     NaN   NaN
# 4    NaN    NaN  NaN     NaN   NaN
# 5    NaN    NaN  NaN     NaN   NaN
# 6    NaN    NaN  NaN     NaN   NaN
# 7    NaN    NaN  NaN     NaN   NaN
# 8    NaN    NaN  NaN     NaN   NaN
# 9    NaN    NaN  NaN     NaN   NaN

# %% [markdown]
# ## 2.1 Tổng quan dữ liệu

# %% [markdown]
# ### 2.1.1 Thông tin cơ bản

# %%
print("Số dòng trong dataset là: ",len(df))
print("Số cột trong dataset là: ",df.shape[-1])
# Out:
# Số dòng trong dataset là:  64005
# Số cột trong dataset là:  14

# %%
print("Mỗi dòng sẽ biểu diễn thông tin về doanh số của một game")
df.sample()
# Out:
# Mỗi dòng sẽ biểu diễn thông tin về doanh số của một game
#             name        date platform publisher developer  shipped  total  \
# 8735  Mega Man 7  1995-03-23     SNES    Capcom    Capcom      NaN   0.28
#
#       america  europe  japan  other  vgc  critic  user
# 8735     0.03    0.01   0.23   0.01  NaN     NaN   NaN

# %%
print(f"Kích thước của dataset gồm {df.shape[0]} dòng, {df.shape[-1]} cột")
# Out:
# Kích thước của dataset gồm 64005 dòng, 14 cột

# %% [markdown]
# ### 2.1.2 Tính toàn vẹn dữ liệu

# %%
dup_count = df.duplicated().sum()
print(f"Số dòng bị lặp lại trong dataset là: {dup_count}")

df = df.drop_duplicates()
print("Đã loại bỏ các dòng trùng lặp khỏi dataset.")
# Out:
# Số dòng bị lặp lại trong dataset là: 23
# Đã loại bỏ các dòng trùng lặp khỏi dataset.

# %% [markdown]
# Ở đây em chọn loại bỏ các dòng bị trùng lặp vì các dữ liệu này là có 3 thuộc tính để xác định nó là duy nhất là một tên game,ngày phát hành,nền tảng,duy nhất nên không phải ngẫu nhiên có thể trùng lặp nên sự trùng lặp dòng này là do sơ suất không phải dữ liệu ngẫu nhiên trùng lặp

# %%
empty_cols = df.columns[df.isnull().all()].tolist()
if empty_cols:
    print("Các cột trống hoàn toàn:", empty_cols)
else:
    print("Không có cột nào trống hoàn toàn.")
# Out:
# Không có cột nào trống hoàn toàn.

# %% [markdown]
# ### 2.1.3 Danh mục cột

# %% [markdown]
#  Ý nghĩa của từng cột trong dataset:
#  - name: tên của trò chơi điện tử.
#  - date: ngày phát hành trò chơi điện tử.
#  - platform: nền tảng chơi game (All – tất cả nền tảng, Series – toàn bộ series game).
#  - publisher: nhà phát hành.
#  - developer: nhà phát triển.
#  - shipped: số lượng bản đã xuất xưởng (chỉ áp dụng với các bản ghi có platform là All hoặc Series).
#  - total: tổng số bản đã bán ra (tính theo triệu bản).
#  - america: số bản bán tại khu vực Châu Mỹ (triệu bản).
#  - europe: số bản bán tại khu vực Châu Âu (triệu bản).
#  - japan: số bản bán tại Nhật Bản (triệu bản).
#  - other: số bản bán ở các khu vực khác trên thế giới.
#  - vgc: điểm đánh giá từ VGChartz.com.
#  - critic: đánh giá từ giới phê bình.
#  - user: đánh giá từ người dùng.
#
#  Một số cột tiềm năng có thể phân tích gồm:
#  - date: giúp phân tích xu hướng phát hành game theo thời gian, xác định các mốc tăng trưởng, mùa vụ,...
#  - platform: nghiên cứu sự khác biệt về doanh số, thị phần hoặc điểm đánh giá giữa các nền tảng hoặc series.
#  - publisher & developer: có thể phân tích mức độ thành công của từng nhà phát hành/nhà phát triển.
#  - critic & user: cho phép so sánh giữa đánh giá chuyên môn và đánh giá từ người chơi, phân tích các yếu tố ảnh hưởng đến điểm số.
#
# Không có cột nào nên được drop vì từng cột sẽ có ý nghĩa để phân tích khác nhau tùy theo khía cạnh

# %% [markdown]
# ### 2.1.4 Kiểu dữ liệu

# %%
print("Kiểu dữ liệu hiện tại của các cột")
print(df.dtypes)
print("Cột date có kiểu dữ liệu object thay vì datetime")
# Chuyển cột 'date' từ object sang kiểu datetime
df['date'] = pd.to_datetime(df['date'], errors='coerce')
print("Đã chuyển kiểu dữ liệu date từ object sang", df['date'].dtype)
# Out:
# Kiểu dữ liệu hiện tại của các cột
# name          object
# date          object
# platform      object
# publisher     object
# developer     object
# shipped      float64
# total        float64
# america      float64
# europe       float64
# japan        float64
# other        float64
# vgc          float64
# critic       float64
# user         float64
# dtype: object
# Cột date có kiểu dữ liệu object thay vì datetime
# Đã chuyển kiểu dữ liệu date từ object sang datetime64[ns]

# %% [markdown]
# ## 2.2 Phân tích cột dạng số

# %%
numeric_cols = [
    "shipped", "total", "america", "europe", "japan", 
    "other", "vgc", "critic", "user",
    "date"
]

print("Numeric:", numeric_cols)

def detect_distribution(data):
    skew = data.skew()
    if abs(skew) < 0.5:
        return "Approximately Normal"
    elif skew > 0:
        return "Right-Skewed"
    else:
        return "Left-Skewed"

for col in numeric_cols:
    print(f"\n===== COLUMN: {col.upper()} =====")

    # ===== SPECIAL CASE: DATE =====
    if col == "date":
        series = df["date"].dt.year
        series_name = "year (from date)"
    else:
        series = pd.to_numeric(df[col], errors="coerce")
        series_name = col

    mean = series.mean()
    median = series.median()
    std = series.std()
    min_val = series.min()
    max_val = series.max()

    print(f"Mean   : {mean}")
    print(f"Median : {median}")
    print(f"Std Dev: {std}")
    print(f"Min    : {min_val}")
    print(f"Max    : {max_val}")

    Q1 = series.quantile(0.25)
    Q3 = series.quantile(0.75)
    IQR = Q3 - Q1

    lower_bound = Q1 - 1.5 * IQR
    upper_bound = Q3 + 1.5 * IQR

    outliers = series[(series < lower_bound) | (series > upper_bound)].count()
    print(f"Outliers (IQR method): {outliers}")

    dist_type = detect_distribution(series.dropna())
    print(f"Distribution: {dist_type}")

    missing_pct = series.isna().mean() * 100
    print(f"Missing values: {missing_pct:.2f}%")

    placeholder = series.isin([0, -1, 999]).sum()
    print(f"Suspicious placeholders (0, -1, 999): {placeholder}")

    negative_values = (series < 0).sum()
    print(f"Negative values: {negative_values}")

    # ===== VISUALIZATION =====
    plt.figure(figsize=(10, 3))

    plt.subplot(1, 2, 1)
    plt.hist(series.dropna(), bins=30)
    plt.title(f"{series_name} - Histogram")

    plt.subplot(1, 2, 2)
    plt.boxplot(series.dropna(), vert=False)
    plt.title(f"{series_name} - Boxplot")

    plt.tight_layout()
    plt.show()
# Out:
# Numeric: ['shipped', 'total', 'america', 'europe', 'japan', 'other', 'vgc', 'critic', 'user', 'date']
#
# ===== COLUMN: SHIPPED =====
# Mean   : 4.733955845911241
# Median : 1.0
# Std Dev: 21.082158125836045
# Min    : 0.0
# Max    : 520.0
# Outliers (IQR method): 549
# Distribution: Right-Skewed
# Missing values: 93.06%
# Suspicious placeholders (0, -1, 999): 16
# Negative values: 0
# ===== COLUMN: TOTAL =====
# Mean   : 0.3491283894497595
# Median : 0.12
# Std Dev: 0.807516960412828
# Min    : 0.0
# Max    : 20.32
# Outliers (IQR method): 1963
# Distribution: Right-Skewed
# Missing values: 70.43%
# Suspicious placeholders (0, -1, 999): 1352
# Negative values: 0
# ===== COLUMN: AMERICA =====
# Mean   : 0.26474004906227744
# Median : 0.12
# Std Dev: 0.49478659622522564
# Min    : 0.0
# Max    : 9.76
# Outliers (IQR method): 1210
# Distribution: Right-Skewed
# Missing values: 80.25%
# Suspicious placeholders (0, -1, 999): 280
# Negative values: 0
# ===== COLUMN: EUROPE =====
# Mean   : 0.1494720835932626
# Median : 0.04
# Std Dev: 0.3926526251894326
# Min    : 0.0
# Max    : 9.85
# Outliers (IQR method): 1409
# Distribution: Right-Skewed
# Missing values: 79.96%
# Suspicious placeholders (0, -1, 999): 2245
# Negative values: 0
# ===== COLUMN: JAPAN =====
# Mean   : 0.1022147850661907
# Median : 0.04
# Std Dev: 0.16870850315720026
# Min    : 0.0
# Max    : 2.13
# Outliers (IQR method): 629
# Distribution: Right-Skewed
# Missing values: 89.49%
# Suspicious placeholders (0, -1, 999): 420
# Negative values: 0
# ===== COLUMN: OTHER =====
# Mean   : 0.0430407191961925
# Median : 0.01
# Std Dev: 0.12664349644249281
# Min    : 0.0
# Max    : 3.12
# Outliers (IQR method): 1931
# Distribution: Right-Skewed
# Missing values: 76.36%
# Suspicious placeholders (0, -1, 999): 5165
# Negative values: 0
# ===== COLUMN: VGC =====
# Mean   : 7.093566739606127
# Median : 7.3
# Std Dev: 1.546587598875291
# Min    : 1.0
# Max    : 10.0
# Outliers (IQR method): 21
# Distribution: Left-Skewed
# Missing values: 96.43%
# Suspicious placeholders (0, -1, 999): 0
# Negative values: 0
# ===== COLUMN: CRITIC =====
# Mean   : 7.215509957754978
# Median : 7.5
# Std Dev: 1.4578130500307702
# Min    : 1.0
# Max    : 10.0
# Outliers (IQR method): 147
# Distribution: Left-Skewed
# Missing values: 89.64%
# Suspicious placeholders (0, -1, 999): 0
# Negative values: 0
# ===== COLUMN: USER =====
# Mean   : 8.059661835748793
# Median : 8.5
# Std Dev: 1.6673305517086372
# Min    : 1.0
# Max    : 10.0
# Outliers (IQR method): 33
# Distribution: Left-Skewed
# Missing values: 99.35%
# Suspicious placeholders (0, -1, 999): 0
# Negative values: 0
# ===== COLUMN: DATE =====
# Mean   : 2006.3095004382121
# Median : 2008.0
# Std Dev: 8.722572120660324
# Min    : 1970.0
# Max    : 2024.0
# Outliers (IQR method): 848
# Distribution: Left-Skewed
# Missing values: 10.83%
# Suspicious placeholders (0, -1, 999): 0
# Negative values: 0

# %% [markdown]
# Đánh giá cột SHIPPED:
# - Phân bố lệch phải cực mạnh (mean 4.73 >> median 1.0), max 520 cho thấy một vài tựa game bán cực chạy.
# - Độ lệch chuẩn rất lớn (21.08) và 549 outliers xác nhận hiện tượng “hit” hiếm nhưng cực lớn.
# - Tỷ lệ missing cực cao (93.06%) → hầu hết dữ liệu không có thông tin shipped.
# - Với 16 giá trị 0 khả nghi và mức missing này, cột gần như không dùng được nếu chưa bổ sung/impute dữ liệu đáng tin cậy.

# %% [markdown]
# Đánh giá cột TOTAL:
# - Phân bố lệch phải cực mạnh (mean 0.35 >> median 0.12), max 20.32.
# - Độ lệch chuẩn cao (0.81) và có 1963 outliers cho thấy vài giá trị cực đại kéo mean lên.
# - Tỷ lệ missing rất lớn (70.44%), cộng thêm 1352 giá trị nghi ngờ (0, -1, 999) → dữ liệu thiếu nghiêm trọng và cần làm sạch kỹ.
# - Hiện tại cột này không đáng tin cậy để tính toán hoặc báo cáo nếu chưa xử lý missing + outliers.

# %% [markdown]
# Đánh giá cột AMERICA:
# - Phân bố lệch phải mạnh (mean 0.26 > median 0.12), max 9.76.
# Độ lệch chuẩn 0.49 và 1210 outliers cho thấy một số ít game bán rất tốt tại Mỹ.
# - Tỷ lệ missing rất cao (80.26%), kèm 280 giá trị 0 khả nghi → dữ liệu thiếu nghiêm trọng.
# - Cột hiện không đáng tin để phân tích hoặc báo cáo nếu chưa xử lý missing và outliers kỹ lưỡng.

# %% [markdown]
# Phân bố lệch phải mạnh (mean 0.15 >> median 0.04), max 9.85.
# - Độ lệch chuẩn 0.39 và 1409 outliers cho thấy vài tựa game bán cực tốt ở châu Âu.
# - Tỷ lệ missing rất cao (79.96%), kèm tới 2245 giá trị 0 khả nghi → dữ liệu thiếu nghiêm trọng và ô nhiễm nặng.
# - Cột này hiện gần như không thể sử dụng nếu chưa xử lý missing + làm sạch giá trị 0 giả mạo.

# %% [markdown]
# Đánh giá cột JAPAN:
# - Phân bố lệch phải (mean 0.10 > median 0.04), max chỉ 2.13 cho thấy doanh số Nhật Bản thường rất thấp.
# - Độ lệch chuẩn 0.17 và 630 outliers phản ánh một số ít game Nhật bán tốt nội địa.
# - Tỷ lệ missing cực cao (89.49%), kèm 420 giá trị 0 khả nghi → dữ liệu thiếu nghiêm trọng và ô nhiễm nặng.
# - Cột gần như vô dụng ở trạng thái hiện tại nếu chưa bổ sung/làm sạch dữ liệu đáng kể

# %% [markdown]
# Đánh giá cột OTHER:
# - Phân bố lệch phải mạnh (mean 0.043 >> median 0.01), max 3.12.
# Độ lệch chuẩn 0.13 và tới 1931 outliers cho thấy vài game bán tốt ở khu vực “Other”.
# - Tỷ lệ missing cao (76.36%), đặc biệt nghiêm trọng với 5165 giá trị 0 khả nghi → ô nhiễm dữ liệu cực nặng.
# - Cột hiện tại không đáng tin cậy, gần như không dùng được nếu chưa xử lý triệt để missing và giá trị 0 giả.

# %% [markdown]
# Đánh giá cột VGC:
# - Phân bố gần đối xứng, hơi lệch trái (mean 7.09 < median 7.3), giá trị tập trung quanh 7–8.
# - Độ lệch chuẩn thấp (1.55), chỉ 21 outliers → chất lượng điểm số khá ổn định khi có dữ liệu.
# - Tuy nhiên missing cực cao (96.43%) → chỉ ~3.57% bản ghi có điểm VGC.
# - Cột chỉ nên dùng cho phân tích có điều kiện (khi dữ liệu tồn tại), không đại diện toàn bộ dataset.

# %% [markdown]
# Đánh giá cột CRITIC:
# - Phân bố hơi lệch trái (mean 7.22 < median 7.5), điểm trung bình khá cao và tập trung 7–8.
# - Độ lệch chuẩn thấp (1.46), 147 outliers → chất lượng điểm số ổn định, ít giá trị cực đoan.
# - Không có giá trị nghi ngờ, dữ liệu sạch khi tồn tại.
# - Tuy nhiên missing rất cao (89.64%) → chỉ ~10% bản ghi có điểm critic, chỉ dùng được cho phân tích có điều kiện.

# %% [markdown]
# Đánh giá cột USER:
# - Phân bố lệch trái nhẹ (mean 8.06 < median 8.5), điểm user thường rất cao (8–9).
# - Độ lệch chuẩn 1.67, chỉ 33 outliers → dữ liệu sạch, ít cực đoan khi tồn tại.
# - Không có giá trị nghi ngờ, chất lượng tốt.
# - Nhưng missing cực kỳ cao (99.35%) → chỉ ~0.65% bản ghi có điểm user, gần như không đại diện, chỉ dùng được cho mẫu rất nhỏ.

# %% [markdown]
# Đánh giá cột DATE:
# - Dữ liệu năm trải dài rộng (1970–2024) và hơi lệch trái, cho thấy nhiều giá trị tập trung ở các năm gần đây hơn.
# - Độ lệch chuẩn khá lớn, phản ánh sự biến động đáng kể giữa các năm.
# - Số lượng outliers cao (848) cho thấy dữ liệu có thể chứa các năm bất thường hoặc lỗi nhập liệu.
# - Tỷ lệ thiếu 10.83% là đáng kể và cần xử lý trước khi phân tích theo năm.
# - Không xuất hiện các giá trị placeholder bất thường, dữ liệu phần lớn hợp lệ.

# %% [markdown]
# ## 2.3 Phân tích cột dạng phân loại

# %% [markdown]
# Chúng ta sẽ phân tích các cột phân loại (categorical) trong dataset:
# - `name`, `platform`, `publisher`, `developer`

# %%
categorical_cols = ["name", "platform", "publisher", "developer"]
print("Categorical:", categorical_cols)
# Out:
# Categorical: ['name', 'platform', 'publisher', 'developer']

# %% [markdown]
# #### Phân bố giá trị (Value Distribution)
#
# Kiểm tra cho mỗi cột:
# - Số lượng giá trị duy nhất
# - Top 5 giá trị phổ biến nhất kèm tỷ lệ %
# - Biểu đồ tần suất (count plot)
# - Xem phân bố cân bằng hay lệch

# %%
for col in categorical_cols:
    print(f"=== Cột: {col} ===")
    
    # Số giá trị duy nhất
    n_unique = df[col].nunique(dropna=True)
    print(f"Số giá trị duy nhất: {n_unique}")
    
    # Top 5 giá trị phổ biến + % so với tổng
    top5 = df[col].value_counts().head(5)
    top5_pct = df[col].value_counts(normalize=True).head(5) * 100
    print("Top 5 giá trị phổ biến (số lượng và %):")
    for val, cnt, pct in zip(top5.index, top5.values, top5_pct.values):
        print(f"- {val}: {cnt} lần, chiếm {pct:.2f}% tổng số")
    
    # Biểu đồ tần suất (top 10)
    plt.figure(figsize=(8,4))
    top10 = df[col].value_counts().head(10)
    sns.barplot(x=top10.values, y=top10.index)
    plt.xlabel("Số lượng")
    plt.ylabel(col)
    plt.title(f"Top 10 giá trị phổ biến cho cột {col}")
    plt.show()
    
    print("\n")
# Out:
# === Cột: name ===
# Số giá trị duy nhất: 39762
# Top 5 giá trị phổ biến (số lượng và %):
# - Plants vs. Zombies: 17 lần, chiếm 0.03% tổng số
# - Pac-Man: 16 lần, chiếm 0.03% tổng số
# - Monopoly: 15 lần, chiếm 0.02% tổng số
# - Double Dragon: 14 lần, chiếm 0.02% tổng số
# - Doom: 14 lần, chiếm 0.02% tổng số
# === Cột: platform ===
# Số giá trị duy nhất: 81
# Top 5 giá trị phổ biến (số lượng và %):
# - PC: 12582 lần, chiếm 19.66% tổng số
# - PS2: 3563 lần, chiếm 5.57% tổng số
# - DS: 3287 lần, chiếm 5.14% tổng số
# - PS4: 2880 lần, chiếm 4.50% tổng số
# - PS: 2707 lần, chiếm 4.23% tổng số
# === Cột: publisher ===
# Số giá trị duy nhất: 3383
# Top 5 giá trị phổ biến (số lượng và %):
# - Unknown: 8804 lần, chiếm 13.76% tổng số
# - Sega: 2208 lần, chiếm 3.45% tổng số
# - Ubisoft: 1664 lần, chiếm 2.60% tổng số
# - Electronic Arts: 1618 lần, chiếm 2.53% tổng số
# - Activision: 1581 lần, chiếm 2.47% tổng số
# === Cột: developer ===
# Số giá trị duy nhất: 8862
# Top 5 giá trị phổ biến (số lượng và %):
# - Unknown: 4434 lần, chiếm 6.93% tổng số
# - Konami: 976 lần, chiếm 1.53% tổng số
# - Sega: 913 lần, chiếm 1.43% tổng số
# - Capcom: 870 lần, chiếm 1.36% tổng số
# - Namco: 489 lần, chiếm 0.76% tổng số

# %% [markdown]
# Nhận xét:
# - Cột "name" phân bố khá đều.
# - Cột "platform" phân bố đều, với nền tảng PC chiếm số lượng lớn nhất (khoảng 20% tổng số), số lượng nền tảng khá ít so với số lượng tựa game, nhà phát hành, nhà phát triển.
# - Cột "publisher" và "developer" có số lượng giá trị "Unknown" lớn hơn hẳn so với các giá trị hợp lệ khác, nhưng tỉ lệ Unknown không quá lớn (chỉ từ 6-13%)

# %% [markdown]
# #### Chất lượng dữ liệu (Data Quality)
#
# Kiểm tra:
# - Tỷ lệ giá trị thiếu
# - Các giá trị bất thường hoặc không nhất quán
# - Các category ít xuất hiện có thể cần gộp

# %%
for col in categorical_cols:
    print(f"=== Cột: {col} ===")
    
    # Tỷ lệ missing
    missing_pct = df[col].isna().mean() * 100
    print(f"Tỷ lệ giá trị thiếu: {missing_pct:.2f}%")
    
    # Các giá trị duy nhất (sample) để kiểm tra inconsistencies/typos
    unique_vals = df[col].unique()
    print(f"Một số giá trị duy nhất (max 20 giá trị): {unique_vals[:20]}")
    
    # Các category ít xuất hiện (<5 lần)
    value_counts = df[col].value_counts()
    rare_categories = value_counts[value_counts < 5]
    
    if len(rare_categories) > 0:
        # Tỷ lệ % số category hiếm so với tổng số category duy nhất
        rare_pct = len(rare_categories) / len(value_counts) * 100
        print(f"Các category ít xuất hiện (<5 lần):")
        print(rare_categories)
        print(f"Tỷ lệ các category hiếm so với tổng số category: {rare_pct:.2f}%")
    else:
        print("Không có category ít xuất hiện (<5 lần).")
    
    print("\n")
# Out:
# === Cột: name ===
# Tỷ lệ giá trị thiếu: 0.00%
# Một số giá trị duy nhất (max 20 giá trị): ['Tetris' 'Pokemon' 'Call of Duty' 'Grand Theft Auto' 'Super Mario' 'FIFA'
#  'Minecraft' 'Lego' "Assassin's Creed" 'The Sims' 'Grand Theft Auto V'
#  'Final Fantasy' 'Mario Kart' 'The Legend of Zelda' 'Need for Speed'
#  'Resident Evil' 'Tomb Raider' 'NBA 2K' 'Madden NFL' 'Wii/Nintendo Sports']
# Các category ít xuất hiện (<5 lần):
# name
# Five Nights at Freddy's 3           4
# NHL 24                              4
# The Raven Remastered                4
# NHL 22                              4
# Merv Griffin's Crosswords           4
#                                    ..
# Zombie Brigade: No Brain No Gain    1
# ZOMBIE GOLD RUSH                    1
# Nintendo Puzzle Collection          1
# Zombillie                           1
# Ultimate Surfing                    1
# Name: count, Length: 38022, dtype: int64
# Tỷ lệ các category hiếm so với tổng số category: 95.62%
#
#
# === Cột: platform ===
# Tỷ lệ giá trị thiếu: 0.00%
# Một số giá trị duy nhất (max 20 giá trị): ['Series' 'All' 'Wii' 'NS' 'NES' 'PC' 'GB' 'DS' 'X360' 'PS4' 'SNES' 'PS3'
#  '3DS' 'PS2' 'GBA' 'GEN' 'N64' 'PS' 'XOne' 'WiiU']
# Các category ít xuất hiện (<5 lần):
# platform
# CD32    3
# FMT     3
# S32X    3
# TG16    3
# C128    1
# BBCM    1
# Aco     1
# FDS     1
# Name: count, dtype: int64
# Tỷ lệ các category hiếm so với tổng số category: 9.88%
#
#
# === Cột: publisher ===
# Tỷ lệ giá trị thiếu: 0.00%
# Một số giá trị duy nhất (max 20 giá trị): ['The Tetris Company' 'Nintendo' 'Activision' 'Rockstar Games' 'EA Sports'
#  'Mojang' 'Warner Bros. Interactive Entertainment' 'Ubisoft'
#  'Electronic Arts' 'Square' 'Capcom' 'Eidos Interactive' '2K Games'
#  'Konami' 'Sega' 'Bethesda Softworks' 'Sony Interactive Entertainment'
#  'Microsoft Game Studios' 'PUBG Corporation' 'CD Projekt']
# Các category ít xuất hiện (<5 lần):
# publisher
# Destructive Creations    4
# Back To Basics Gaming    4
# P2 Games                 4
# Rune                     4
# Paranoid Productions     4
#                         ..
# VRChat Inc.              1
# Isbit Games              1
# AIGRIND                  1
# Household Games          1
# Walkabout                1
# Name: count, Length: 2297, dtype: int64
# Tỷ lệ các category hiếm so với tổng số category: 67.90%
#
#
# === Cột: developer ===
# Tỷ lệ giá trị thiếu: 0.03%
# Một số giá trị duy nhất (max 20 giá trị): ['Alexey Pajitnov' 'Game Freak' 'Infinity Ward' 'Rockstar North'
#  'Nintendo' 'Extended Play Productions (1991-1997)' 'Mojang' 'Mojang AB'
#  'TT Fusion' 'Ubisoft' 'Maxis' 'Square' 'EA Black Box' 'Capcom'
#  'Core Design' 'Visual Concepts' 'Park Place Productions' 'Konami'
#  'Sonic Team' 'Bethesda Softworks']
# Các category ít xuất hiện (<5 lần):
# developer
# Double Six                            4
# Rondomedia                            4
# SmileBoom                             4
# Gateway Interactive                   4
# Paper Castle Games                    4
#                                      ..
# Nival Interactive / N-Game Studios    1
# Ides                                  1
# Multitude                             1
# Maddox Games                          1
# Pumpkin Studios                       1
# Name: count, Length: 6554, dtype: int64
# Tỷ lệ các category hiếm so với tổng số category: 73.96%

# %% [markdown]
# Nhận xét:
# - Cột "name" có 96% giá trị có số lần xuất hiện ít, vậy có gần 5% tựa game có nhiều lượt phát hành hoặc nền tảng hoặc nhà phát triển.
# - Cột "platform" có rất ít giá trị xuất hiện ít hơn 5 lần, nghĩa là đa số các game đều được chơi trên các nền tảng lớn.
# - Cột "publisher" và "developer" có giá trị xuất hiện dưới 5 lần khá nhiều, vậy có thể nói nhiều nhà phát hành và nhà phát triển nhỏ lẻ.
# - Đa số các cột đều không bị thiếu giá trị, chỉ có cột developer bị thiếu nhưng rất ít.

# %% [markdown]
# ## 2.4 Phân tích dữ liệu bị thiếu

# %%
missing_summary = pd.DataFrame({
    'Column': df.columns,
    'Missing Count': df.isna().sum(),
    'Missing Percentage': df.isna().mean() * 100
})

missing_summary
# Out:
#               Column  Missing Count  Missing Percentage
# name            name              0            0.000000
# date            date           6932           10.834297
# platform    platform              0            0.000000
# publisher  publisher              0            0.000000
# developer  developer             17            0.026570
# shipped      shipped          59543           93.062111
# total          total          45063           70.430746
# america      america          51345           80.249133
# europe        europe          51158           79.956863
# japan          japan          57259           89.492357
# other          other          48854           76.355850
# vgc              vgc          61697           96.428683
# critic        critic          57354           89.640836
# user            user          63568           99.352943

# %%
# Bar plot of missing value percentage per column
plt.figure(figsize=(10, 6))

sns.barplot(
    x=missing_summary['Missing Percentage'],
    y=missing_summary['Column'],
    hue=missing_summary['Column'],  # Assign hue
    palette='viridis',
    legend=False    # Do not show legend
)
plt.xlabel("Missing Percentage (%)")
plt.ylabel("Column")
plt.title("Percentage of Missing Data by Column")
plt.xlim(0, 100)
plt.show()

# %% [markdown]
# Nhận xét và giải thích tại sao giá trị của các cột lại bị thiếu:
# - Dữ liệu bị thiếu không phân bố hoàn toàn ngẫu nhiên. Một số cột như "shipped", "total", "america", "europe", "japan", "other", có tỷ lệ thiếu rất cao, có thể giải thích được bởi vì "shipped" giá trị xuất xưởng chỉ áp dụng cho tổng hợp nên nếu trường "Platform" có giá trị là 'All' hoặc 'Series' thì giá trị ở 'shipped' là có hoặc trống còn các trường còn lại như "total", "america", "europe", "japan", "other" chắc chắn là trống, các trường này chỉ có thể giá trị nếu platform là khác 'Series' hoặc 'All',còn nếu có thể có giá trị về doanh số "total" là cột thực sự được bán ra cho người tiêu dùng cuối cùng thì số liệu bán ra thực tế quan trọng hơn cột "shipped" nên không được ghi song song giá trị 2 cột này.<br>
# Đây là các mẫu thiết kế cho bộ dataset này nên dẫn đến giá trị của các cột này tỷ lệ thiếu cao
#
# - Còn đối với các cột đánh giá như "vgc","critic","user" có thể là dữ liệu có nhiều tựa game không nổi tiếng dẫn đến không có thông tin gì về đánh giá nên các cột này cũng có tỉ lệ thiếu cao
#
# - Cột "date" cũng có tỷ lệ thiếu đáng kể (~10.8%). Nguyên nhân thường gặp là nhiều tựa game cũ, đặc biệt là những game phát hành từ rất sớm hoặc các series lớn, không có thông tin chính xác về ngày phát hành đầu tiên, hoặc ngày phát hành không thống nhất giữa các khu vực, hệ máy, phiên bản. Ngoài ra, đôi khi với các bộ dữ liệu tổng hợp theo "series" hoặc các danh sách đặc biệt, trường "date" bị để trống do không xác định được một ngày phát hành duy nhất đại diện cho toàn bộ series.
#
# Xử lí các giá trị thiếu
# - Đối với các cột "developer" do lí do thiếu là khách quan có thể là ngẫu nhiên,lỗi thu thập nên những dòng nào có cột "developer" là thiếu
#
# - Đối với cột "date" thiếu cũng khá nhiều nên khi xóa có thể sẽ thiếu những nhóm quan trọng nên ở đây sẽ giữ lại và điền bằng giá trị nền tảng đó, nếu nền tảng đó có giá trị trung vị là NaN thì điền tiếp bằng giá trị trung vị của publisher
#
# - Đối với những dòng chỉ có cột "shipped" bị trống và có dữ liệu ở cột total thì vẫn giữ nguyên giá trị NaN vì dòng này mang ý nghĩa là có dữ liệu về số lượng bán ra thực tế
#
# - Đối với những dòng chỉ có cột "total" bị trống và có dữ liệu "shipped" thì vẫn giữ nguyên giá trị NaN vì những dòng này thiếu trên bản ghi (All/Series) hoặc thiếu trên các nền tảng không có dữ liệu bán lẻ chi tiết như đã ghi ở trên, Nan ở đây có nghĩa là dữ liệu không có sẵn
#
# - Đối với những dòng vừa thiếu "shipped" và vừa thiếu "total" vẫn sẽ được giữ nguyên để phân tích và sẽ xóa trước khi đưa vào mô hình dự đoán
#
# - Đối với các cột đánh giá như "vgc","critic","user" dữ liệu thiếu khá nhiều nên có thể cũng sẽ khá ít dữ liệu để dự đoán, nếu dùng các phương pháp để điền thiếu thì rất có thể làm cho dữ liệu sai cao vì giá trị thiếu là rất nhiều nên ở đây các cột này vẫn sẽ giữ nguyên là NaN

# %%
rows_before = len(df)
# Drop rows where 'developer' is NaN
df = df.dropna(subset=['developer'])
# Số dòng sau khi drop
rows_after = len(df)
# In ra số dòng đã drop và số dòng còn lại
print(f"Số dòng đã drop ở cột developer: {rows_before - rows_after}")
print(f"Số dòng còn lại: {rows_after}")
# Out:
# Số dòng đã drop ở cột developer: 17
# Số dòng còn lại: 63965

# %%
# Ép kiểu datetime; chỉnh format/dayfirst nếu cần
df['date'] = pd.to_datetime(df['date'], errors='coerce')

print("Sau to_datetime, số giá trị NaN:", df['date'].isna().sum())

# Điền nan bằng median theo platform
median_by_platform = df.groupby('platform')['date'].transform('median')
df['date'] = df['date'].fillna(median_by_platform)

# Nếu vẫn còn nan (platform cũng toàn nan), thì tiếp tục điền bằng median theo publisher
still_nan_idx = df['date'].isna()
if still_nan_idx.any():
    median_by_publisher = df.groupby('publisher')['date'].transform('median')
    df.loc[still_nan_idx, 'date'] = median_by_publisher[still_nan_idx]

# Kiểm tra
missing_after = df['date'].isna().sum()
print("Số NaN còn lại:", missing_after)
if missing_after:
    # Xem nhóm nào vẫn NaT (nghĩa là nhóm không còn giá trị hợp lệ)
    still_nat = df[df['date'].isna()][['platform', 'publisher']].value_counts()
    print("Platform/Publisher vẫn NaT:", still_nat)
else:
    print("Đã xử lý hết NaN.")
# Out:
# Sau to_datetime, số giá trị NaN: 6926
# Số NaN còn lại: 0
# Đã xử lý hết NaN.

# %% [markdown]
# ## 2.5 Tương quan và mối quan hệ giữa các thuộc tính

# %% [markdown]
# ### 2.5.1 Các pattern sơ bộ
# - Lập ma trận tương quan cho các cột numeric
# - Tạo heatmap tương quan
# - Xác định các cặp thuộc tính tương quan mạnh
# - Tìm các mối quan hệ bất ngờ

# %%
corr_matrix = df[numeric_cols].corr()
print(corr_matrix)

# Heatmap trực quan
plt.figure(figsize=(10,8))
sns.heatmap(corr_matrix, annot=True, fmt=".2f", cmap="coolwarm")
plt.title("Heatmap tương quan các biến numeric")
plt.show()

# Tìm các cặp biến tương quan mạnh (>|0.7|)
threshold = 0.7
strong_corr = []

for i in range(len(corr_matrix.columns)):
    for j in range(i+1, len(corr_matrix.columns)):
        if abs(corr_matrix.iloc[i,j]) >= threshold:
            strong_corr.append((corr_matrix.columns[i], corr_matrix.columns[j], corr_matrix.iloc[i,j]))

print("Các cặp biến numeric có tương quan mạnh (>|0.7|):")
for col1, col2, val in strong_corr:
    print(f"- {col1} và {col2}: {val:.2f}")
# Out:
#           shipped     total   america    europe     japan     other       vgc  \
# shipped  1.000000       NaN       NaN       NaN       NaN       NaN  0.074724
# total         NaN  1.000000  0.914148  0.907418  0.212533  0.859327  0.327771
# america       NaN  0.914148  1.000000  0.684512  0.065091  0.687507  0.330463
# europe        NaN  0.907418  0.684512  1.000000  0.131796  0.817027  0.282648
# japan         NaN  0.212533  0.065091  0.131796  1.000000  0.082653  0.123388
# other         NaN  0.859327  0.687507  0.817027  0.082653  1.000000  0.302496
# vgc      0.074724  0.327771  0.330463  0.282648  0.123388  0.302496  1.000000
# critic   0.221672  0.287038  0.305122  0.249754  0.149127  0.249706  0.740105
# user     0.059742  0.295954  0.285901  0.276709  0.111916  0.279973  0.531174
# date    -0.091296 -0.033686 -0.045821  0.088106 -0.375773  0.092566 -0.178534
#
#            critic      user      date
# shipped  0.221672  0.059742 -0.091296
# total    0.287038  0.295954 -0.033686
# america  0.305122  0.285901 -0.045821
# europe   0.249754  0.276709  0.088106
# japan    0.149127  0.111916 -0.375773
# other    0.249706  0.279973  0.092566
# vgc      0.740105  0.531174 -0.178534
# critic   1.000000  0.549433  0.015651
# user     0.549433  1.000000 -0.057638
# date     0.015651 -0.057638  1.000000
# Các cặp biến numeric có tương quan mạnh (>|0.7|):
# - total và america: 0.91
# - total và europe: 0.91
# - total và other: 0.86
# - europe và other: 0.82
# - vgc và critic: 0.74

# %% [markdown]
#  Nhận xét về các mối quan hệ giữa các biến numeric
#
# 1. **`total` với các khu vực (`america`, `europe`, `other`)**
# - Các cặp này có tương quan rất cao (>0.85), điều này hoàn toàn hợp lý vì `total` là tổng doanh số ở các khu vực.
# 2. **`europe` – `other`**
# - Tương quan ~0.82, thể hiện doanh số giữa các khu vực ngoài châu Âu và châu Mỹ có xu hướng di chuyển cùng nhau đối với các game bán chạy.
# 3. **`vgc` và `critic`**
# - Tương quan ~0.74, hợp lý vì điểm VGC và điểm critic thường đồng thuận trong đánh giá game.
# 4. **Các cặp khác (`shipped`, `japan`, `user` với các biến còn lại)**
# - Tương quan thấp (<0.3) với hầu hết các biến khác.
# - Không có pattern mạnh, phản ánh rằng số lượng game xuất xưởng (`shipped`) hay điểm đánh giá người dùng (`user`) không liên quan trực tiếp đến doanh số khu vực khác hoặc điểm critic/VGC.
# - Một số cặp như `japan` với `america` hay `europe` có tương quan rất thấp (~0.06 – 0.13), có thể do một số game bán tốt ở Mỹ/Âu nhưng không bán mạnh ở Nhật hoặc ngược lại.
# 5. **Kết luận chung**
# - Các mối tương quan mạnh đều **hợp lý và dễ dự đoán**, chủ yếu là do cấu trúc dữ liệu.
# - Không xuất hiện mối quan hệ numeric nào thật sự “bất ngờ” nếu chỉ dựa vào ma trận tương quan tổng thể.

# %% [markdown]
# ### 2.5.2 Phân tích chéo dữ liệu (Cross-tabulations)
# - Phân tích các cột phân loại × phân loại (Categorical × Categorical) bằng bảng tần số.
# - Phân tích các cột số × phân loại (Numerical × Categorical) bằng thống kê nhóm.

# %% [markdown]
# #### Phân tích Categorical × Categorical
#
# Tạo bảng tần số cho các cặp cột phân loại quan trọng, ví dụ:
# - `platform` × `publisher`
# - `platform` × `developer`

# %%
cat_pairs = [
    ("publisher", "platform"),
    ("developer", "platform"),
    ("publisher", "developer"),
]

topN = 10

for cat1, cat2 in cat_pairs:
    print(f"\n=== {cat1} × {cat2} (Top {topN}) ===")
    
    top1 = df[cat1].value_counts().head(topN).index
    top2 = df[cat2].value_counts().head(topN).index
    
    sub = df[df[cat1].isin(top1) & df[cat2].isin(top2)]
    
    ct = pd.crosstab(sub[cat1], sub[cat2])
    display(ct)
# Out:
# === publisher × platform (Top 10) ===
# platform                      DS   NS    PC   PS  PS2  PS3  PS4  PSN   XBL  \
# publisher
# Activision                   124    4   263   43  125  117   40   25    31
# Electronic Arts               81    8   413   68   91   91   41   98    92
# Konami                       132    8    61  171  258   37    8   53    33
# Microsoft                      0    0    54    0    0    0    0    0  1172
# Nintendo                     157  104     1    0    0    0    0    0     0
# Sega                          74   29   222    0  142   67   44   43    38
# Sony Computer Entertainment    0    0     8  225  251  160   64  405     0
# THQ                          121    1   130   35  111   47    1   29    33
# Ubisoft                      192   27   314   27   77   93   74   56    38
# Unknown                      172  702  2900   26   58  199  800  214   164
#
# platform                     XOne
# publisher
# Activision                     40
# Electronic Arts                40
# Konami                          6
# Microsoft                       0
# Nintendo                        0
# Sega                           24
# Sony Computer Entertainment     0
# THQ                             1
# Ubisoft                        70
# Unknown                       620
# === developer × platform (Top 10) ===
# platform         DS  NS    PC  PS  PS2  PS3  PS4  PSN  XBL  XOne
# developer
# Capcom           24  39    79  56   45   28   56   37   10    42
# EA Canada         6   0    54  24   56   35   11   13   10    11
# Hudson Soft      43   0     3   5   20    0    0   22    1     0
# Konami           91  14    40  87  124   22   11   25    6     6
# Namco             5  26    10  59   56    1   27    8    4     1
# SNK Corporation   0  69     9  16    3    0   54   30    1    65
# Sega             36  22    99   0   30   18   34   13    3    19
# Square Enix      25  49    67   2   32   11   57   16    2    22
# Ubisoft          53  13    56   1   12   14   26   18    3    22
# Unknown          63   7  1069  64   29  253  117    2    7    40
# === publisher × developer (Top 10) ===
# developer                    Capcom  EA Canada  Hudson Soft  Konami  Namco  \
# publisher
# Activision                        0          0            1       0      0
# Electronic Arts                   0         67            0       1      0
# Konami                            0          0           21     829      0
# Microsoft                         0          0            1       0      0
# Nintendo                          5          0           23       4      9
# Sega                              6          0            3       2      0
# Sony Computer Entertainment      12          0            1       1     11
# THQ                               0          0            0       0      0
# Ubisoft                           3          0            3       1      1
# Unknown                          92          5            7      57     60
#
# developer                    SNK Corporation  Sega  Square Enix  Ubisoft  \
# publisher
# Activision                                 0     6            0        0
# Electronic Arts                            0     0            0        0
# Konami                                     0     0            0        0
# Microsoft                                  0     0            0        0
# Nintendo                                   0     0           15        2
# Sega                                       1   814            0        0
# Sony Computer Entertainment                3     0            0        2
# THQ                                        0     3            0        0
# Ubisoft                                    0     2            0      326
# Unknown                                   13    60           61       37
#
# developer                    Unknown
# publisher
# Activision                        51
# Electronic Arts                   39
# Konami                             3
# Microsoft                          7
# Nintendo                          32
# Sega                              53
# Sony Computer Entertainment       15
# THQ                               18
# Ubisoft                           78
# Unknown                          875

# %% [markdown]
# #### Phân tích các cột Numerical x Categorical

# %%
pairs = [
    ('publisher', 'critic'),
    ('publisher', 'user'),
    ('publisher', 'total'),
    ('developer', 'critic'),
    ('developer', 'user'),
    ('developer', 'total'),
    ('platform', 'critic'),
    ('platform', 'user'),
    ('platform', 'total'),
    ('publisher', 'america')
]


for cat, num in pairs:
    if num not in df.columns:
        print(f"Bỏ qua cặp {cat} - {num} (không tồn tại)")
        continue
    # chọn top 10 giá trị cate phổ biến nhất
    top_vals = df[cat].value_counts().head(10).index
    sub = df[df[cat].isin(top_vals)]

    plt.figure(figsize=(12,6))
    sns.barplot(data=sub, x=cat, y=num, estimator='mean', errorbar=None)
    plt.title(f"{num} trung bình theo {cat} (Top 10 {cat})")
    plt.xticks(rotation=45, ha='right')
    plt.tight_layout()
    plt.show()

# %% [markdown]
# ## 2.6 Quan sát sơ bộ và các ý tưởng

# %% [markdown]
# ### 2.6.1 Tổng quan
# 1. Dữ liệu doanh số bị thiếu cực kỳ nghiêm trọng và không đồng nhất giữa các nền tảng
#
# Các cột như shipped, total, america, europe, japan, other có tỷ lệ thiếu từ 70%–93%, cùng với hàng nghìn giá trị 0 hoặc placeholder bất thường. Đây không phải lỗi ngẫu nhiên mà xuất phát từ thiết kế dataset, đặc biệt khi nền tảng mang giá trị All/Series hoặc không có ghi nhận bán lẻ theo khu vực. Điều này cho thấy việc sử dụng các biến doanh số cho phân tích hoặc mô hình cần được cân nhắc rất cẩn thận.
#
# 2. Các cột đánh giá (VGC, Critic, User) có chất lượng tốt nhưng thiếu dữ liệu nghiêm trọng
#
# Mặc dù phân bố điểm khá “sạch” và logic, nhưng tỷ lệ NaN lên đến 89–99%, dẫn đến việc các cột này chỉ có giá trị phân tích hạn chế. Dữ liệu thiếu nhiều đến mức không thể áp dụng các phương pháp imputation thông thường mà không gây méo phân phối, do đó nhiều phân tích sẽ bị giới hạn hoặc phải loại bỏ hoàn toàn các cột này.
#
# 3. Các biến thời gian (YEAR, SEASON) là nhóm dữ liệu ổn định và hữu ích nhất
#
# YEAR và SEASON gần như là các cột numeric duy nhất có chất lượng tốt (10.83% missing) và có thể sử dụng cho phân tích theo thời gian. YEAR hơi lệch trái và có nhiều outliers đáng nghi, trong khi SEASON phân bố gần chuẩn. Đây là nhóm biến có giá trị cao cho việc phân nhóm theo thời gian, theo quý, xu hướng phát hành, hoặc nghiên cứu hành vi thị trường theo mùa.
#
# 4. Dữ liệu danh mục (name, platform, publisher, developer) đa dạng nhưng phân bố không đều
#
# Platform có phân bố rõ ràng với PC chiếm ưu thế. Ngược lại, publisher và developer chứa nhiều giá trị hiếm xuất hiện, phản ánh ngành công nghiệp game phân mảnh và có nhiều nhà phát triển nhỏ. Số lượng lớn giá trị “Unknown” cũng cho thấy vấn đề hụt thông tin trong quá trình thu thập dữ liệu.
#
# 5. Mối tương quan giữa các biến numeric chủ yếu là quan hệ hiển nhiên và mang tính cấu trúc
#
# total tương quan rất mạnh với america, europe, other do công thức cộng lại.
#
# vgc và critic tương quan cao vì đều là thang đánh giá chất lượng game.
#
# Các biến còn lại có tương quan yếu → không có mẫu hành vi bất thường hoặc mối quan hệ tiềm ẩn nào nổi bật.
# Điều này cho thấy dataset không có pattern numeric phức tạp, và các câu hỏi chuyên sâu sẽ phải dựa vào phân tích theo thời gian hoặc theo nhóm danh mục thay vì tương quan numeric.
#
# ### 2.6.2 Red Flags (Các vấn đề nghiêm trọng)
# 1. Tỷ lệ missing cực cao và có tính hệ thống ở các cột doanh số
#
# Nhiều cột có 70–90% dữ liệu trống và còn chứa hàng nghìn giá trị bất thường (0, -1, 999). Điều này khiến phần lớn các biến doanh số không phù hợp để dùng cho mô hình hóa hoặc phân tích thống kê chuẩn.
#
# 2. Dữ liệu đánh giá thiếu trầm trọng, gần như không thể xây dựng mô hình dự đoán dựa trên điểm số
#
# USER missing 99%, VGC missing 96%, CRITIC missing 89% → nếu cố gắng điền giá trị sẽ gây méo dữ liệu nặng. Đây là hạn chế lớn trong mọi nghiên cứu liên quan đến chất lượng game.
#
# 3. Nhiều cột chứa outliers lớn bất thường và cần kiểm tra bổ sung
#
# YEAR có 848 outliers, và các cột doanh số có hàng nghìn giá trị lệch chuẩn rất khó xử lý. Cần xem xét đây là lỗi dữ liệu hay đặc trưng thực tế.

# %% [markdown]
# # 3. Các câu hỏi có ý nghĩa và phân tích trả lời

# %% [markdown]
# ## Câu hỏi 1: Publisher và Developer có phối hợp ăn ý không?

# %% [markdown]
# ## Câu hỏi 2: Theo thời gian, platform nào phát triển, platform nào "chết"?

# %% [markdown]
# ## Câu hỏi 3: Các khu vực như Bắc Mỹ, châu Âu, Nhật Bản có mô hình tiêu thụ game khác nhau như thế nào giữa các nền tảng, và nền tảng nào thể hiện sự vượt trội rõ rệt tại từng khu vực?

# %% [markdown]
# ### Động lực & Lợi ích
# - Thị trường game toàn cầu không đồng nhất. Nhu cầu, sở thích và sự thâm nhập của các nền tảng console/PC/thiết bị di động khác nhau đáng kể giữa các khu vực. Phân tích này giúp định lượng sự khác biệt đó.
# - Cung cấp cái nhìn trực quan về sự phân bổ sức mạnh thị trường của các nền tảng theo khu vực. Giúp xác định các nền tảng "thống trị" hoặc "yếu thế" tại từng thị trường cụ thể.
# - Nhà phát triển và Nhà phát hành Game (Stakeholders): Giúp họ quyết định nền tảng (Platform) nào cần ưu tiên phát hành hoặc marketing mạnh mẽ hơn ở từng khu vực (ví dụ: một game thiên về RPG có thể tập trung vào thị trường Nhật Bản/châu Âu trên nền tảng A). Nhà sản xuất Console/Phần cứng (Decision-makers): Đánh giá hiệu suất thị trường của thiết bị của họ so với đối thủ cạnh tranh ở các khu vực địa lý khác nhau. Nhà nghiên cứu thị trường: Hiểu rõ xu hướng tiêu thụ game toàn cầu.
# - Thông báo quyết định Phân bổ Nguồn lực và Chiến lược Phát hành Toàn cầu. Thay vì áp dụng chiến lược "one-size-fits-all", công ty có thể điều chỉnh ngân sách tiếp thị và tối ưu hóa nền tảng cho từng thị trường khu vực.

# %% [markdown]
# ### Preprocessing
# - Mục tiêu: Đảm bảo chỉ phân tích các hàng dữ liệu thể hiện doanh số bán lẻ cá nhân của trò chơi theo khu vực, loại bỏ các mục tổng hợp (ví dụ: platform = 'Series') hoặc các hàng không có dữ liệu doanh số khu vực.
#
# - Bước 1: Xác định các cột Doanh số: Định nghĩa một danh sách các cột doanh số khu vực và tổng (sales_cols = ["america", "europe", "japan", "other", "total"]).
#
# - Bước 2: Lọc bỏ Hàng thiếu: Sử dụng phương pháp df.dropna() với tham số subset=sales_cols và how="all" để chỉ giữ lại các hàng có ít nhất một giá trị doanh số khu vực hoặc tổng. Điều này giúp loại bỏ các mục tổng hợp cấp cao mà không chứa thông tin chi tiết khu vực.

# %% [markdown]
# ### Analysis
# - Mục tiêu: So sánh sự khác biệt về sức mạnh thị trường của các nền tảng bằng cách sử dụng Doanh số bán hàng trung bình.
#
# - Phương pháp (Thống kê Mô tả): Tính toán Doanh số Trung bình của từng khu vực ("america", "europe", "japan", "other") cho mỗi platform bằng cách sử dụng hàm groupby().mean(). Doanh số trung bình giúp chuẩn hóa và làm giảm ảnh hưởng của số lượng game được phát hành trên mỗi nền tảng.
#
# - Phương pháp (Tìm kiếm Đỉnh cao): Xác định nền tảng mạnh nhất (idxmax()) cho từng khu vực để trả lời phần hai của câu hỏi (nền tảng nào vượt trội rõ rệt).
#
# - Phương pháp (Trực quan hóa):
#
#     Biểu đồ Cột (Bar Chart): Hiển thị rõ ràng sự khác biệt về độ lớn của doanh số trung bình giữa các nền tảng và khu vực.
#
#     Biểu đồ Nhiệt (Heatmap): Cung cấp một cái nhìn tổng quan, trực quan về mô hình tiêu thụ (pattern) giữa các cặp Platform-Khu vực. Màu sắc đậm hơn biểu thị doanh số trung bình cao hơn, làm nổi bật ngay lập tức các thị trường thống trị của từng nền tảng.

# %%
# 1. Chỉ giữ những dòng có đủ thông tin doanh số
# (Tránh các dòng platform = 'Series' hoặc không có sales theo khu vực)
sales_cols = ["america", "europe", "japan", "other", "total"]
df_sales = df.dropna(subset=sales_cols, how="all")

print("Số dòng còn lại sau khi lọc:", len(df_sales))

# 2. Tính doanh số trung bình theo từng nền tảng
platform_region_mean = df_sales.groupby("platform")[["america", "europe", "japan", "other"]].mean().sort_values("america", ascending=False)
print(platform_region_mean.head())

# 3. VẼ BIỂU ĐỒ SO SÁNH DOANH SỐ GIỮA CÁC PLATFORM THEO TỪNG KHU VỰC
plt.figure(figsize=(14,8))
platform_region_mean.plot(kind="bar", figsize=(14, 7))
plt.title("So sánh doanh số trung bình theo Platform và Khu vực")
plt.xlabel("Platform")
plt.ylabel("Doanh số trung bình (triệu bản)")
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# 4. TÌM NỀN TẢNG MẠNH NHẤT Ở MỖI KHU VỰC
best_platforms = {
    "America": platform_region_mean["america"].idxmax(),
    "Europe": platform_region_mean["europe"].idxmax(),
    "Japan": platform_region_mean["japan"].idxmax(),
    "Other": platform_region_mean["other"].idxmax()
}

print("\n=== Nền tảng mạnh nhất theo từng khu vực ===")
for region, plat in best_platforms.items():
    print(f"{region}: {plat}")

# 5. HEATMAP để xem pattern tiêu thụ giữa region-platform
plt.figure(figsize=(10,6))
sns.heatmap(platform_region_mean, annot=True, cmap="Blues")
plt.title("Heatmap doanh số trung bình theo Platform và Khu vực")
plt.show()
# Out:
# Số dòng còn lại sau khi lọc: 18915
#            america    europe     japan     other
# platform
# GEN       1.394444  0.404444  0.093182  0.038125
# DC        1.125000  0.305000  0.156809  0.007407
# GB        0.920000  0.500000  0.366739  0.007368
# GBC       0.895000  0.525000  0.460000  0.040000
# SNES      0.570000  0.132727  0.296062  0.002680
# === Nền tảng mạnh nhất theo từng khu vực ===
# America: GEN
# Europe: GBC
# Japan: NES
# Other: PS4

# %% [markdown]
# ### Results & Interpretation
# 1. Nền tảng Mạnh nhất cho từng khu vực:
#
# Mô hình tiêu thụ game phân cực mạnh mẽ giữa phương Tây và Nhật Bản, với các nền tảng vượt trội về doanh số trung bình như sau:
#
# America: GEN (1.39 triệu bản/game)
#
# Europe: GBC (0.525 triệu bản/game)
#
# Japan: NES (0.723 triệu bản/game)
#
# Other: PS4 (0.028 triệu bản/game)
#
# 2. Diễn giải Mô hình Tiêu thụ:
#
# Phân cực Thị trường: America và Europe có mô hình tương đồng, trong khi Japan là thị trường độc lập, ưa chuộng các nền tảng Nintendo cổ điển (NES, GBC, SNES).
#
# Sức mạnh của Retro: Các nền tảng đời đầu (GEN, DC, GB) chiếm ưu thế cao về doanh số trung bình, cho thấy sự ảnh hưởng của các "bom tấn" lịch sử hoặc các vấn đề dữ liệu liên quan đến việc gộp "Series".
#
# GBC thể hiện sự cân bằng tốt nhất, có doanh số cao ở cả ba khu vực chính.
#
# 3. Hàm ý thực tế:
#
# Nhà phát hành cần áp dụng chiến lược đa dạng: ưu tiên Nintendo tại Nhật Bản và tập trung vào các nền tảng console/PC tại phương Tây để tối đa hóa lợi nhuận theo từng khu vực. Cần điều tra lại sự thống trị của các nền tảng quá cũ (GEN, DC) để đảm bảo chất lượng dữ liệu.

# %% [markdown]
# ## Câu hỏi 4: Xu hướng phát hành và doanh số game thay đổi như thế nào theo từng năm? Liệu có thể quan sát được các mô hình dài hạn của thị trường game qua thời gian hay không?

# %% [markdown]
# ### Motivation & Benefits
# - Sự phát triển của ngành công nghiệp game phụ thuộc vào các chu kỳ phát hành console và sự thay đổi trong hành vi người tiêu dùng. Phân tích này giúp định vị các giai đoạn bùng nổ và suy thoái của thị trường.
# - Xác định chu kỳ sống (Life Cycle) của thị trường game (ví dụ: các đỉnh điểm doanh số tương ứng với các thế hệ console). Đo lường mối quan hệ giữa số lượng sản phẩm (games released) và sức khỏe thị trường (total sales).
# - Nhà đầu tư và Phân tích Thị trường: Đánh giá độ rủi ro và tiềm năng tăng trưởng của ngành game, xác định thời điểm đầu tư tối ưu. * Nhà phát triển game: Hiểu được sự cạnh tranh thay đổi như thế nào theo năm (thông qua số lượng game phát hành). Giám đốc điều hành: Xây dựng chiến lược dài hạn dựa trên chu kỳ thị trường.
# - Thông báo quyết định Lập kế hoạch Sản phẩm và Cấu trúc Thị trường (Product Planning and Market Structuring). Dự đoán thời điểm bão hòa của thị trường và chuẩn bị cho các đợt suy thoái/tái cấu trúc.

# %% [markdown]
# ### Preprocessing
# - Mục tiêu: Chuẩn bị dữ liệu cho phân tích chuỗi thời gian, đảm bảo rằng mỗi dòng đều có thông tin cần thiết về thời gian và doanh số khu vực.
#
# - Bước 1: Lọc bỏ Hàng thiếu: Lọc bỏ các hàng thiếu giá trị trong bất kỳ cột nào sau đây: "year", "total", "america", "europe", "japan", "other" (sử dụng how="any"). Việc này đảm bảo chỉ phân tích các game có đầy đủ dữ liệu doanh số khu vực và năm phát hành.
#
# - Bước 2: Chuyển đổi Kiểu dữ liệu: Chuyển đổi cột "year" từ kiểu dữ liệu chuỗi/float sang kiểu số nguyên (int) để đảm bảo việc phân nhóm và vẽ biểu đồ thời gian được chính xác.

# %% [markdown]
# ### Analysis
# - Mục tiêu: Khám phá xu hướng dài hạn của thị trường bằng cách theo dõi sự thay đổi của tổng doanh số và số lượng game được phát hành theo năm.
#
# - Phương pháp (Tổng hợp Dữ liệu Thời gian): Tính tổng doanh số cho mỗi khu vực và tổng toàn cầu (total) theo từng năm (groupby("year").sum()).
#
# - Phương pháp (Đo lường Cung): Đếm số lượng game được phát hành mỗi năm (groupby("year").count()) để đo lường mức độ cạnh tranh và cung cấp sản phẩm.
#
# - Phương pháp (Tương quan): Tính hệ số tương quan Pearson giữa Tổng Doanh số và Số lượng Game Phát hành theo năm. Hệ số này giúp định lượng mối quan hệ: liệu việc phát hành nhiều game hơn có đồng nghĩa với doanh số cao hơn trên toàn thị trường hay không.
#
# - Phương pháp (Trực quan hóa): Sử dụng Biểu đồ Đường (Line Plots) để dễ dàng xác định các đỉnh, đáy và mô hình dài hạn (ví dụ: tăng trưởng, bão hòa, suy giảm) của doanh số và số lượng game theo thời gian.

# %%
# 1. Lọc các dòng có thông tin năm và có doanh số
df["date"] = pd.to_datetime(df["date"], errors="coerce")

# Extract year from date
df["year"] = df["date"].dt.year

year_cols = ["year", "total", "america", "europe", "japan", "other"]
df_year = df.dropna(subset=year_cols, how="any")

# Chuyển year sang int nếu cần
df_year["year"] = df_year["year"].astype(int)

print("Số dòng còn lại sau khi lọc:", len(df_year))

# 2. Tính doanh số trung bình theo từng năm
yearly_sales = df_year.groupby("year")[["total", "america", "europe", "japan", "other"]].sum()

print("5 dòng đầu của bảng doanh số theo năm:")
print(yearly_sales.head())

# 3. Vẽ biểu đồ đường theo thời gian — tổng doanh số toàn cầu
plt.figure(figsize=(14,7))
plt.plot(yearly_sales.index, yearly_sales["total"])
plt.title("Xu hướng tổng doanh số game theo từng năm")
plt.xlabel("Năm phát hành")
plt.ylabel("Tổng doanh số (triệu bản)")
plt.grid(True)
plt.tight_layout()
plt.show()

# 4. Vẽ biểu đồ đường cho từng khu vực
plt.figure(figsize=(14,7))
plt.plot(yearly_sales.index, yearly_sales["america"], label="America")
plt.plot(yearly_sales.index, yearly_sales["europe"], label="Europe")
plt.plot(yearly_sales.index, yearly_sales["japan"], label="Japan")
plt.plot(yearly_sales.index, yearly_sales["other"], label="Other")

plt.title("Xu hướng doanh số theo từng khu vực qua các năm")
plt.xlabel("Năm")
plt.ylabel("Doanh số (triệu bản)")
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()

# 5. Phân tích số lượng game phát hành mỗi năm
games_per_year = df_year.groupby("year")["platform"].count()

plt.figure(figsize=(14,7))
plt.plot(games_per_year.index, games_per_year.values)
plt.title("Số lượng game phát hành theo từng năm")
plt.xlabel("Năm")
plt.ylabel("Số lượng game")
plt.grid(True)
plt.tight_layout()
plt.show()

# 6. Kết hợp để xem năm nào 'bùng nổ' game
trend_df = pd.DataFrame({
    "total_sales": yearly_sales["total"],
    "games_released": games_per_year
})

print("\n5 dòng đầu của bảng xu hướng:")
print(trend_df.head())

# Tương quan giữa số game phát hành và doanh số
corr = trend_df.corr().iloc[0,1]
print(f"\nHệ số tương quan giữa số game phát hành và tổng doanh số: {corr:.2f}")
# Out:
# Số dòng còn lại sau khi lọc: 2222
# 5 dòng đầu của bảng doanh số theo năm:
#       total  america  europe  japan  other
# year
# 1985   0.82     0.42    0.10   0.28   0.02
# 1986   2.28     0.66    0.17   1.43   0.02
# 1987   2.04     0.99    0.14   0.89   0.02
# 1988   0.96     0.32    0.06   0.57   0.01
# 1989   4.17     3.38    0.44   0.31   0.04
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_41284\3170372181.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_year["year"] = df_year["year"].astype(int)
# 5 dòng đầu của bảng xu hướng:
#       total_sales  games_released
# year
# 1985         0.82               1
# 1986         2.28               2
# 1987         2.04               2
# 1988         0.96               1
# 1989         4.17               1
#
# Hệ số tương quan giữa số game phát hành và tổng doanh số: 0.98

# %% [markdown]
# ### Results & Interpretation
# 1. Trả lời Câu hỏi Trực tiếp:
# Xu hướng phát hành và doanh số game thể hiện rõ ràng mô hình chu kỳ mạnh mẽ của thị trường, được dẫn dắt bởi các chu kỳ phát hành console.
# - Tổng Doanh số (Total Sales): Thị trường game đạt đỉnh cao rõ rệt vào khoảng năm 2010-2011, với tổng doanh số hàng năm vượt qua 200 triệu bản. Sau đó, thị trường bước vào giai đoạn suy thoái đáng kể, giảm mạnh về cuối thời kỳ dữ liệu (2018-2020).
# - Số lượng Game Phát hành: Số lượng game phát hành cũng đạt đỉnh vào khoảng năm 2010, tương ứng với đỉnh doanh số. Điều này xác nhận rằng việc tăng trưởng cung cấp sản phẩm đã song hành với nhu cầu thị trường.
# - Mối quan hệ Cung-Cầu: Hệ số tương quan giữa số lượng game phát hành và tổng doanh số là $0.98$, cho thấy một mối quan hệ tích cực gần như hoàn hảo giữa hai yếu tố này.
# 2. Mô hình Dài hạn và Khu vực:
# - Động lực Chính: Biểu đồ xu hướng doanh số theo khu vực  cho thấy thị trường America và Europe là hai động lực chính, chiếm phần lớn doanh số toàn cầu và quyết định đỉnh điểm thị trường vào năm 2010-2011.
# - Thị trường Nhật Bản: Doanh số của Japan ổn định hơn, nhưng có sự tăng trưởng nhẹ và duy trì một khoảng cách đáng kể so với America/Europe.
# - Hàm ý: Thị trường game hoạt động theo chu kỳ console rõ ràng, với đỉnh doanh số thường xảy ra khi các console thế hệ thứ 7 (PS3/Xbox 360/Wii) đạt độ bão hòa và có một thư viện game khổng lồ. Sự sụt giảm sau đó có thể do sự chuyển đổi sang các mô hình doanh thu khác (như game kỹ thuật số, Free-to-Play, Mobile) không được thống kê đầy đủ trong dữ liệu bán lẻ vật lý này.

# %% [markdown]
# ## Câu hỏi 5: “Game được đánh giá cao (critic/user/VGC) có thực sự bán chạy hơn không, ở mức toàn cầu và từng khu vực?”

# %% [markdown]
# ## 5.1 Motivation & Benefits

# %% [markdown]
# ## 5.2 Preprocessing
# Mục tiêu tiền xử lí
# - Chỉ giữ lại các bản dòng có 'total' không phải là NaN để phân tích
# - Tạo một biến mới global_sales là trộn thông tin total và doanh số theo vùng
#
# Quy trình tiền xử lý
# - Bước 1: Tạo bản sao dữ liệu gốc mục đích tránh làm thay đổi dataframe gốc nếu sau này cần dùng lại cho bài toán khác.
# - Bước 2: Xóa các dòng có platform là "Series" hoặc "All" lý do vì đây là các bản ghi tổng hợp cho cả series hoặc cho toàn bộ nền tảng vì câu hỏi phân tích tập trung vào mối quan hệ điểm – doanh số của từng bản phát hành trên một platform cụ thể, nên giữ các bản ghi tổng hợp sẽ gây trùng/khó diễn giải.
# - Bước 3: Loại bỏ các dòng hoàn toàn không có thông tin doanh số tức là loại bỏ dòng nếu tất cả cột 'total', 'america', 'europe','japan','other' đều mang giá trị NaN
# - Bước 4: Tạo biến doanh số toàn cầu thống nhất global_sales mặc định lấy total, nếu bị thiếu thì sẽ lấy tổng các vùng còn lại vì một số bản ghi chỉ có total, số khác chỉ có doanh số theo vùng nên biến này giúp ta có một biến duy nhất đại diện cho doanh số toàn cầu “tốt nhất có thể” từ mọi nguồn dữ liệu sẵn có.

# %% [markdown]
# ## 5.3 Analysis
#
# Mục tiêu phân tích
# - Xem mức độ tương quan tuyến tính giữa điểm số và doanh số toàn cầu.
# - Quan sát hình dạng mối quan hệ qua scatter plot.
# - Kiểm tra xu hướng “điểm cao → doanh số trung bình cao hơn” bằng cách nhóm điểm thành các khoảng.
# Các bước phân tích
# - Tính ma trận tương quan global_sales,critic,user,vgc để xem một cách trực quan về sự tương quan mối quan hệ giữa các biến đánh giá so với biến global_sales
# - Vẽ 3 biểu đồ scatter plot của từng biến đánh giá so với global_sales vì biểu đồ này dễ dàng nhận thấy quan hệ tuyến tính
# - Chia theo khoảng điểm của 3 cột đánh giá và so sánh doanh số trung bình theo nhóm điểm và trực quan bằng biểu đồ bar, vì Scatter thể hiện những điểm dữ liệu riêng biệt nên rất nhiễu, khi lấy trung bình theo nhóm điểm thì làm giảm ảnh hưởng của outlier,

# %%
# Sao chép toàn bộ df để làm việc mà không ảnh hưởng đến df gốc
df_analysis = df.copy()

# Các cột vùng và numeric
region_cols = ['america', 'europe', 'japan', 'other']
score_cols = ['vgc', 'critic', 'user']
num_cols = ['shipped', 'total'] + region_cols + score_cols

# ======================
# 2. Lọc dữ liệu phù hợp với câu hỏi
# ======================

# Bỏ các dòng 'Series' và 'All' vì không phải platform cụ thể
df_analysis = df_analysis[~df_analysis['platform'].isin(['Series', 'All'])].copy()

# Bỏ những dòng hoàn toàn không có thông tin doanh số
# (cả total và 4 vùng đều NaN)
df_analysis = df_analysis.dropna(subset=['total'] + region_cols, how='all').copy()

# Tạo biến "global_sales": doanh số toàn cầu tốt nhất có thể
# - Nếu 'total' có thì dùng
# - Nếu 'total' thiếu mà các vùng có số liệu thì dùng tổng các vùng
df_analysis['regions_sum'] = df_analysis[region_cols].sum(axis=1, min_count=1)
df_analysis['global_sales'] = df_analysis['total']
mask = df_analysis['global_sales'].isna() & df_analysis['regions_sum'].notna()
df_analysis.loc[mask, 'global_sales'] = df_analysis.loc[mask, 'regions_sum']

# Giữ lại những dòng có global_sales để phân tích mối quan hệ với điểm
df_trim = df_analysis[df_analysis['global_sales'].notna()].copy()

# %%
print("Mô tả thống kê cho doanh số & điểm số:")
print(df_trim[['global_sales'] + score_cols].describe())
# Out:
# Mô tả thống kê cho doanh số & điểm số:
#        global_sales         vgc       critic        user
# count  18915.000000  798.000000  4098.000000  161.000000
# mean       0.349190    7.406642     7.097438    8.102484
# std        0.807591    1.403846     1.438520    1.353004
# min        0.000000    2.000000     1.000000    2.500000
# 25%        0.030000    6.700000     6.300000    7.500000
# 50%        0.120000    7.700000     7.300000    8.300000
# 75%        0.345000    8.500000     8.100000    9.000000
# max       20.320000    9.700000    10.000000   10.000000

# %%
# Chỉ lấy những dòng có đủ thông tin điểm + doanh số
eda_global = df_trim[['global_sales'] + score_cols].dropna(how='any')

# Ma trận tương quan Pearson
corr = eda_global.corr(method='pearson')
print("Ma trận tương quan (Pearson):")
print(corr)

# Heatmap tương quan
plt.figure(figsize=(6, 4))
sns.heatmap(corr, annot=True, fmt=".2f", cmap='coolwarm', vmin=-1, vmax=1)
plt.title("Tương quan giữa doanh số toàn cầu và điểm đánh giá")
plt.tight_layout()
plt.show()
# Out:
# Ma trận tương quan (Pearson):
#               global_sales       vgc    critic      user
# global_sales      1.000000  0.321337  0.565297  0.224498
# vgc               0.321337  1.000000  0.789806  0.391823
# critic            0.565297  0.789806  1.000000  0.546718
# user              0.224498  0.391823  0.546718  1.000000

# %%
plt.figure(figsize=(7, 5))
sns.scatterplot(data=eda_global, x='critic', y='global_sales', alpha=0.4)
plt.title('Critic score vs Global sales')
plt.xlabel('Critic score')
plt.ylabel('Global sales (triệu bản)')
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(7, 5))
sns.scatterplot(data=eda_global, x='user', y='global_sales', alpha=0.4, color='orange')
plt.title('User score vs Global sales')
plt.xlabel('User score')
plt.ylabel('Global sales (triệu bản)')
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(7, 5))
sns.scatterplot(data=eda_global, x='vgc', y='global_sales', alpha=0.4, color='green')
plt.title('VGC score vs Global sales')
plt.xlabel('VGC score')
plt.ylabel('Global sales (triệu bản)')
plt.tight_layout()
plt.show()

# %%
# Tạo bin cho critic score
bins = [0, 5, 7, 8, 9, 10]
labels = ['<=5', '5-7', '7-8', '8-9', '9-10']

df_scorebin = df_trim.copy()
df_scorebin = df_scorebin[df_scorebin['critic'].notna() & df_scorebin['global_sales'].notna()]
df_scorebin['critic_bin'] = pd.cut(df_scorebin['critic'], bins=bins, labels=labels, include_lowest=True)

grouped = (df_scorebin.groupby('critic_bin')['global_sales']
                     .agg(['count', 'mean', 'median'])
                     .reset_index())

print(grouped)

plt.figure(figsize=(7, 5))
sns.barplot(data=grouped, x='critic_bin', y='mean', color='steelblue')
plt.title('Doanh số trung bình theo nhóm Critic score')
plt.xlabel('Nhóm Critic score')
plt.ylabel('Global sales trung bình (triệu bản)')
plt.tight_layout()
plt.show()
# Out:
#   critic_bin  count      mean  median
# 0        <=5    419  0.267780    0.14
# 1        5-7   1374  0.432009    0.21
# 2        7-8   1176  0.605204    0.33
# 3        8-9    939  1.143376    0.58
# 4       9-10    190  2.521947    1.29
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_41284\2350016959.py:9: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped = (df_scorebin.groupby('critic_bin')['global_sales']

# %%
bins_user = [0, 5, 7, 8, 9, 10]
labels_user = ['<=5', '5-7', '7-8', '8-9', '9-10']

df_userbin = df_trim.copy()
df_userbin = df_userbin[df_userbin['user'].notna() & df_userbin['global_sales'].notna()]
df_userbin['user_bin'] = pd.cut(df_userbin['user'], bins=bins_user, labels=labels_user, include_lowest=True)

grouped_user = (df_userbin.groupby('user_bin')['global_sales']
                           .agg(['count', 'mean', 'median'])
                           .reset_index())

print(grouped_user)

plt.figure(figsize=(7, 5))
sns.barplot(data=grouped_user, x='user_bin', y='mean', color='orange')
plt.title('Doanh số trung bình theo nhóm User score')
plt.xlabel('Nhóm User score')
plt.ylabel('Global sales trung bình (triệu bản)')
plt.tight_layout()
plt.show()
# Out:
# C:\Users\Dell\AppData\Local\Temp\ipykernel_3116\2409032767.py:8: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped_user = (df_userbin.groupby('user_bin')['global_sales']
#   user_bin  count      mean  median
# 0      <=5      5  0.182000    0.05
# 1      5-7     25  0.470400    0.22
# 2      7-8     40  0.748500    0.23
# 3      8-9     52  2.079808    0.78
# 4     9-10     39  1.795897    1.10
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_41284\2409032767.py:8: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped_user = (df_userbin.groupby('user_bin')['global_sales']

# %%
bins_vgc = [0, 5, 7, 8, 9, 10]
labels_vgc = ['<=5', '5-7', '7-8', '8-9', '9-10']

df_vgcbin = df_trim.copy()
df_vgcbin = df_vgcbin[df_vgcbin['user'].notna() & df_vgcbin['global_sales'].notna()]
df_vgcbin['vgc_bin'] = pd.cut(df_vgcbin['vgc'], bins=bins_vgc, labels=labels_vgc, include_lowest=True)

grouped_user = (df_vgcbin.groupby('vgc_bin')['global_sales']
                           .agg(['count', 'mean', 'median'])
                           .reset_index())

print(grouped_user)

plt.figure(figsize=(7, 5))
sns.barplot(data=grouped_user, x='vgc_bin', y='mean', color='red')
plt.title('Doanh số trung bình theo nhóm vgc score')
plt.xlabel('Nhóm vgc score')
plt.ylabel('Global sales trung bình (triệu bản)')
plt.tight_layout()
plt.show()
# Out:
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_41284\3882478248.py:8: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped_user = (df_vgcbin.groupby('vgc_bin')['global_sales']
#   vgc_bin  count      mean  median
# 0     <=5      1  0.260000   0.260
# 1     5-7      5  0.434000   0.430
# 2     7-8     11  1.450909   0.740
# 3     8-9     22  3.086364   1.265
# 4    9-10     11  2.887273   2.830
# C:\Users\Dell\AppData\Local\Temp\ipykernel_3116\3882478248.py:8: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped_user = (df_vgcbin.groupby('vgc_bin')['global_sales']

# %% [markdown]
# ## 5.4 Kết luận
#
# Xét theo biểu đồ scatter cho thấy các điểm dữ liệu phân tán khá mạnh; ở cùng một mức điểm đối với cả 3 đánh giá,doanh số có thể dao động từ gần 0 đến vài triệu bản. Điều này cho thấy điểm đánh giá không phải là yếu tố duy nhất quyết định doanh số.
#
# Tuy nhiên, khi nhóm điểm thành các khoảng (≤5, 5-7, 7-8, 8-9, 9-10) và tính doanh số trung bình cho từng nhóm, ta quan sát được xu hướng tăng khá rõ đối với cột critic ở nhóm 9-10 doanh số áp đảo so với các nhóm khách,còn đối với cột vgc và user thì dữ liệu khá ít chỉ vài chục đến vài trăm nhưng lại còn không có xu hướng tăng rõ rệt như đối với critic khi mà nhóm 8-9 lại cao hơn so với 9-10 ở cả 2 cột. Điều này nghĩa là:
#
# Ở mức độ trung bình, game được các nhà phê bình đánh giá cao có xu hướng bán chạy hơn. Ta cũng có thể coi đây là một thuộc tính quan trọng dùng để xây dựng mô hình dự đoán đối với global_sales.
# Nhưng ở từng game cụ thể, mối quan hệ rất nhiễu: có nhiều game điểm cao nhưng bán không tốt
